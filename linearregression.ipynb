# %% [markdown]
# <a href="https://colab.research.google.com/github/83-24/Sai-Jyothi-Sriram/blob/main/linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[1], [5], [10], [15], [20]])
Y = np.array([1,2,2.5,4,5])

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X)

# %%
plt.scatter(X,Y,color="blue")
plt.plot(X,Y_pred,color='red')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept(B0):",model.intercept_)
print("Coefficient(B1):",model.coef_)
# Out:
# Intercept(B0): 0.7742634315424608
# Coefficient(B1): [0.20840555]

# %%
X = np.random.rand(100, 1) * 100
Y = 2 * X + np.random.randn(100, 1) * 10

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')
plt.plot(X, Y_pred, color='red')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [-2.49922629]
# Coefficient (β1): [[2.03091344]]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/diabetes (1).csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=df[["Glucose"]]
Y=df["Age"]
print(X.shape)
print(Y.shape)
# Out:
# (768, 1)
# (768,)

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')
plt.plot(X, Y_pred, color='red')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
